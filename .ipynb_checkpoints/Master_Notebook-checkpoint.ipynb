# %% [markdown]
# # Parental Involvement and Student Performance

# %% [markdown]
# ## Objective
#
# [In an earlier study](https://github.com/anilca-lab/FIS-Mod3-Project), Steven Dye and I tested the hypothesis that student performance is correlated with parental engagement. Using data from the Parent and Family Involvement in Education Survey (2016), we found that higher parental engagement was related with better grades.
#
# <img src="school-involvement.png"> <img src="home-involvement.png">
#
# The following takes this preliminary analysis a step further by controlling for the confounding variables that might be correlated with both parental engagement and student performance. These variables include school, parent, and student characteristics.

# %% [markdown]
# ## Data Preparation
#
# As in the preliminary analysis, I used data from the Parent and Family Involvement in Education Survey (2016). The data was collected as a part of the National Household Education Survey Program, by the National Center for Education Statistics. The survey covered children from grades kindergarten to 12th grade and asks various questions about the child's performance at school, involvement of the parents, as well as other parent, child, and school characteristics. The survey was filled out by the parents (or guardians) and the data was compiled in a csv file with 822 columns and 14075 entries. The data was nationally representative and used a two-stage addressed-based sampling.
#
# ### First step
#
# The initial data preparation included dropping the parts related to home-schooled children, recoding the ordinal features when necessary to reflect continuity, and handling missing values. I used the following approach:
#
#     1. When the number of missing values was large, I dropped the feature.
#     2. When the number of missing values was small, I dropped these observations.
#     3. For categorical features, I maintained the missing values as a seperate category.
#
# This gave me a total of 13,095 observations.
#
# I identified four groups of features as listed below:
#
#     1. School characteristics
#     2. Parent characteristics
#     3. Student characteristics
#     4. Parental involvement
#
# 170 features in total, 42 of them continuous.
#
# I also identified 13 potential target variables.

# %%
# %run data_prep.py

# %%
y_df, school_characteristics_df, parent_characteristics_df, student_characteristics_df, parental_involvement_df, X_cont_labels = select_feats()

# %%
y_df.describe().T
# Out:
#              count      mean       std  min  25%  50%  75%    max
# SEENJOY    13095.0  1.752195  0.700917  1.0  1.0  2.0  2.0    4.0
# SEGRADES   13095.0  2.050477  1.314220  1.0  1.0  2.0  2.0    5.0
# SEADPLCXX  13095.0 -0.012142  1.288855 -1.0 -1.0 -1.0  1.0    2.0
# SEBEHAVX   13095.0  0.508286  2.101060  0.0  0.0  0.0  0.0   75.0
# SESCHWRK   13095.0  0.607637  2.353676  0.0  0.0  0.0  0.0   97.0
# SEGBEHAV   13095.0  1.207560  3.507458  0.0  0.0  0.0  1.0   99.0
# SEGWORK    13095.0  1.190454  3.263526  0.0  0.0  0.0  1.0   99.0
# SEABSNT    13095.0  4.228942  6.943639  0.0  1.0  3.0  5.0  364.0
# SEREPEAT   13095.0  1.923559  0.265713  1.0  2.0  2.0  2.0    2.0
# SESUSOUT   13095.0  1.935319  0.245972  1.0  2.0  2.0  2.0    2.0
# SESUSPIN   13095.0  1.931577  0.252480  1.0  2.0  2.0  2.0    2.0
# SEEXPEL    13095.0  1.986942  0.113529  1.0  2.0  2.0  2.0    2.0
# SEGRADEQ   13095.0  2.062161  0.910598  1.0  1.0  2.0  3.0    5.0

# %%
school_characteristics_df.describe().T
# Out:
#              count      mean       std  min  25%  50%  75%   max
# SCPUBPRI   13095.0  3.756319  0.741296  1.0  4.0  4.0  4.0   4.0
# DISTASSI   13095.0  0.926613  0.765875 -1.0  1.0  1.0  1.0   2.0
# OWNRNTHB   13095.0  1.261168  0.480314  1.0  1.0  1.0   1.0   3.0
# HVINTSPHO  13095.0  1.052692  0.223426  1.0  1.0  1.0   1.0   2.0
# HVINTCOM   13095.0  1.071554  0.257758  1.0  1.0  1.0   1.0   2.0
# ZIP18PO2   13095.0  2.025277  0.964017  1.0  1.0  2.0   3.0   4.0
#
# [81 rows x 8 columns]

# %%
student_characteristics_df.describe().T
# Out:
#              count      mean       std  min  25%   50%   75%   max
# GRADE      13095.0  9.646354  3.835666  2.0  7.0  10.0  13.0  15.0
# FHCAMT     13095.0  1.274609  0.754524 -1.0  1.0   1.0   2.0   3.0
# HDHEALTH   13095.0  1.565178  0.764160  1.0  1.0   1.0   2.0   5.0
# HDINTDIS   13095.0  1.982589  0.130803  1.0  2.0   2.0   2.0   2.0
# HDSPEECHX  13095.0  1.937152  0.242699  1.0  2.0   2.0   2.0   2.0
# HDDISTRBX  13095.0  1.970981  0.167865  1.0  2.0   2.0   2.0   2.0
# HDDEAFIMX  13095.0  1.988163  0.108154  1.0  2.0   2.0   2.0   2.0
# HDBLINDX   13095.0  1.986789  0.114182  1.0  2.0   2.0   2.0   2.0
# HDORTHOX   13095.0  1.978007  0.146667  1.0  2.0   2.0   2.0   2.0
# HDAUTISMX  13095.0  1.975181  0.155578  1.0  2.0   2.0   2.0   2.0
# HDPDDX     13095.0  1.991676  0.090858  1.0  2.0   2.0   2.0   2.0
# HDADDX     13095.0  1.882932  0.321513  1.0  2.0   2.0   2.0   2.0
# HDLEARNX   13095.0  1.933792  0.248656  1.0  2.0   2.0   2.0   2.0
# HDDELAYX   13095.0  1.961741  0.191828  1.0  2.0   2.0   2.0   2.0
# HDTRBRAIN  13095.0  1.994654  0.072920  1.0  2.0   2.0   2.0   2.0
# HDOTHERX   13095.0  1.959756  0.196539  1.0  2.0   2.0   2.0   2.0
# HDRECSER   13095.0 -0.457503  0.980647 -1.0 -1.0  -1.0  -1.0   2.0
# HDSPCLED   13095.0 -0.342955  1.181963 -1.0 -1.0  -1.0  -1.0   2.0
# HDLEARN    13095.0 -0.372509  1.134559 -1.0 -1.0  -1.0  -1.0   2.0
# HDPLAY     13095.0 -0.326231  1.207644 -1.0 -1.0  -1.0  -1.0   2.0
# HDOUT      13095.0 -0.296144  1.251959 -1.0 -1.0  -1.0  -1.0   2.0
# HDFRNDS    13095.0 -0.327300  1.206025 -1.0 -1.0  -1.0  -1.0   2.0
# CHISPAN    13095.0  1.793738  0.404636  1.0  2.0   2.0   2.0   2.0
# CAMIND     13095.0  1.971974  0.165053  1.0  2.0   2.0   2.0   2.0
# CASIAN     13095.0  1.910806  0.285035  1.0  2.0   2.0   2.0   2.0
# CBLACK     13095.0  1.867430  0.339122  1.0  2.0   2.0   2.0   2.0
# CPACI      13095.0  1.989156  0.103572  1.0  2.0   2.0   2.0   2.0
# CWHITE     13095.0  1.231691  0.421929  1.0  1.0   1.0   1.0   2.0
# CHISPRM    13095.0  1.955250  0.206762  1.0  2.0   2.0   2.0   2.0
# CSEX       13095.0  1.486369  0.499833  1.0  1.0   1.0   2.0   2.0
# DISBLTY2X  13095.0  1.757236  0.428770  1.0  2.0   2.0   2.0   2.0

# %%
parental_involvement_df.describe().T
# Out:
#              count      mean       std  min  25%  50%   75%   max
# SEFUTUREX  13095.0  4.966170  1.211422  1.0  4.0  5.0   6.0   6.0
# FSSPORTX   13095.0  1.193967  0.395419  1.0  1.0  1.0   1.0   2.0
# FSVOL      13095.0  1.575181  0.494334  1.0  1.0  2.0   2.0   2.0
# FSMTNG     13095.0  1.136082  0.342889  1.0  1.0  1.0   1.0   2.0
# FSPTMTNG   13095.0  1.554334  0.497058  1.0  1.0  2.0   2.0   2.0
# FSATCNFN   13095.0  1.253761  0.435179  1.0  1.0  1.0   2.0   2.0
# FSFUNDRS   13095.0  1.385949  0.486837  1.0  1.0  1.0   2.0   2.0
# FSCOMMTE   13095.0  1.868881  0.337543  1.0  2.0  2.0   2.0   2.0
# FSCOUNSLR  13095.0  1.637572  0.480720  1.0  1.0  2.0   2.0   2.0
# FSFREQ     13095.0  7.978007  9.032643  0.0  3.0  5.0  10.0  99.0
# FHPLACE    13095.0  1.046354  0.617750 -1.0  1.0  1.0   1.0   3.0
# FHCHECKX   13095.0  3.229630  1.126845  0.0  3.0  4.0   4.0   4.0
# FHHELP     13095.0  1.867812  1.251124  0.0  1.0  2.0   3.0   4.0
# FOSTORY2X  13095.0  1.431768  0.495341  1.0  1.0  1.0   2.0   2.0
# FOCRAFTS   13095.0  1.588087  0.492198  1.0  1.0  2.0   2.0   2.0
# FOGAMES    13095.0  1.517297  0.499720  1.0  1.0  2.0   2.0   2.0
# FOBUILDX   13095.0  1.433753  0.495611  1.0  1.0  1.0   2.0   2.0
# FOSPORT    13095.0  1.267583  0.442716  1.0  1.0  1.0   2.0   2.0
# FORESPON   13095.0  1.292631  0.454988  1.0  1.0  1.0   2.0   2.0
# FOHISTX    13095.0  1.463612  0.498693  1.0  1.0  1.0   2.0   2.0
# FODINNERX  13095.0  4.751737  2.069067  0.0  3.0  5.0   7.0   7.0
# FOLIBRAYX  13095.0  1.671707  0.469610  1.0  1.0  2.0   2.0   2.0
# FOBOOKSTX  13095.0  1.639252  0.480236  1.0  1.0  2.0   2.0   2.0
# FOCONCRTX  13095.0  1.640015  0.480014  1.0  1.0  2.0   2.0   2.0
# FOMUSEUMX  13095.0  1.742039  0.437529  1.0  1.0  2.0   2.0   2.0
# FOZOOX     13095.0  1.800153  0.399901  1.0  2.0  2.0   2.0   2.0
# FOGROUPX   13095.0  1.467583  0.498967  1.0  1.0  1.0   2.0   2.0
# FOSPRTEVX  13095.0  1.591065  0.491656  1.0  1.0  2.0   2.0   2.0
# HDDEVIEPX  13095.0 -0.787018  0.631089 -1.0 -1.0 -1.0  -1.0   2.0

# %% [markdown]
# ### Second step
#
# The second and final step included selecting the target among 13 potential variables, further data cleaning based on the selected target, merging the features to create the X dataframe, dividing the data into training and test samples, and scaling/one-hot encoding the features.

# %% [markdown]
# I selected student grades as the target variable as this provided a more objective and less imbalanced measure of student performance compared to other indicators. I dropped the observations without grades and grouped them into two bins : A and B vis-a-vis C, D, or lower.

# %%
y_df = y_df[['SEGRADES']].loc[(y_df.SEGRADES != 5)]
y_df.SEGRADES.value_counts()
# Out:
# 1    5984
# 2    3908
# 3    1329
# 4     306
# Name: SEGRADES, dtype: int64

# %%
y_df.loc[y_df.SEGRADES == 2, 'SEGRADES'] = 1
y_df.loc[(y_df.SEGRADES == 3) | (y_df.SEGRADES == 4), 'SEGRADES'] = 0
y_df.SEGRADES.value_counts()
# Out:
# 1    9892
# 0    1635
# Name: SEGRADES, dtype: int64

# %%
X_df = school_characteristics_df.merge(parent_characteristics_df, left_index = True, right_index = True)
X_df = X_df.merge(student_characteristics_df, left_index = True, right_index = True)
X_df = X_df.merge(parental_involvement_df, left_index = True, right_index = True)
X_df = X_df.loc[y_df.index]

# %%
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11527 entries, 0 to 14073
# Columns: 170 entries, SCPUBPRI to HDDEVIEPX
# dtypes: int64(170)
# memory usage: 15.0 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, \
                                                    stratify = y_df.SEGRADES, \
                                                    test_size = 0.2, \
                                                    random_state = 20720)

# %% [markdown]
# #### Scaling and one-hot encoding training features:

# %%
X_train_cont = X_train[X_cont_labels]
X_train_cat = X_train.drop(columns = X_train_cont.columns)

# %%
sclr = StandardScaler()
X_train_cont = sclr.fit_transform(X_train_cont)
X_train_cont = pd.DataFrame(sclr.fit_transform(X_train_cont), columns = X_cont_labels)

# %%
encdr = OneHotEncoder(drop = 'first')
encdr.fit(X_train_cat)
# Out:
# OneHotEncoder(categories='auto', drop='first', dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
X_train_cat = encoder_transform(encdr, X_train_cat)

# %%
X_train = pd.concat((X_train_cont, X_train_cat), axis = 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9221 entries, 0 to 9220
# Columns: 278 entries, FSFREQ to HDDEVIEPX_2
# dtypes: float64(278)
# memory usage: 19.6 MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9221 entries, 9167 to 2713
# Data columns (total 1 columns):
# SEGRADES    9221 non-null int64
# dtypes: int64(1)
# memory usage: 144.1 KB

# %% [markdown]
# #### Scaling and one-hot encoding test features:

# %%
X_test_cont = X_test[X_cont_labels]
X_test_cat = X_test.drop(columns = X_cont_labels)
X_test_cont = sclr.transform(X_test_cont)
X_test_cont = pd.DataFrame(X_test_cont, columns = X_cont_labels)
X_test_cat = encoder_transform(encdr, X_test_cat)
X_test = pd.concat((X_test_cont, X_test_cat), axis = 1)
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2306 entries, 0 to 2305
# Columns: 278 entries, FSFREQ to HDDEVIEPX_2
# dtypes: float64(278)
# memory usage: 4.9 MB

# %%
y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2306 entries, 6616 to 6905
# Data columns (total 1 columns):
# SEGRADES    2306 non-null int64
# dtypes: int64(1)
# memory usage: 36.0 KB

# %% [markdown]
# ## Training

# %% [markdown]
# The two classes of the target were significantly imbalanced. Therefore, first, I addressed this class imbalance.

# %%
y_train.SEGRADES.value_counts()
# Out:
# 1    7913
# 0    1308
# Name: SEGRADES, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
X_train, y_train = sm.fit_resample(X_train, y_train.SEGRADES)

# %%
y_train.value_counts()
# Out:
# 1    7913
# 0    7913
# Name: SEGRADES, dtype: int64

# %% [markdown]
# I preferred to use logistic regression as I was interested in explaining rather than merely predicting the student performance. Therefore, I addressed multicollinearity by dropping the features with a VIF above 5. Please note that this process takes a long time to run.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15826 entries, 0 to 15825
# Columns: 278 entries, FSFREQ to HDDEVIEPX_2
# dtypes: float64(278)
# memory usage: 33.6 MB

# %%
# %run training_test.py

# %%
X_train_upd = calculate_vif(X_train)
# Out:
# dropping 'SCPUBPRI_4' at index: 44
# dropping 'DISTASSI_1' at index: 44
# dropping 'SCONSIDR_2' at index: 50
# dropping 'HDSCHLX_1' at index: 58
# dropping 'HDIEPX_1' at index: 59
# dropping 'HDIEPX_2' at index: 59
# dropping 'CENGLPRG_1' at index: 59
# dropping 'FHAMOUNT_1' at index: 60
# dropping 'P1MRSTA_2' at index: 75
# dropping 'P1FRLNG_2' at index: 80
# dropping 'P1SPEAK_2' at index: 84
# dropping 'P1DIFFI_1' at index: 87
# dropping 'P1SCINT_1' at index: 89
# dropping 'P1EMPL_3' at index: 103
# dropping 'P2GUARD_2' at index: 109
# dropping 'P2REL_1' at index: 109
# dropping 'P2SEX_1' at index: 114
# dropping 'P2MRSTA_1' at index: 115
# dropping 'P2MRSTA_2' at index: 115
# dropping 'P2FRLNG_1' at index: 120
# dropping 'P2FRLNG_2' at index: 120
# dropping 'P2SPEAK_2' at index: 124
# dropping 'P2DIFFI_1' at index: 127
# dropping 'P2SCINT_1' at index: 129
# dropping 'P2PLCBRTH_1' at index: 132
# dropping 'P2HISPAN_1' at index: 134
# dropping 'P2AMIND_1' at index: 135
# dropping 'P2ASIAN_1' at index: 136
# dropping 'P2BLACK_1' at index: 137
# dropping 'P2PACI_1' at index: 138
# dropping 'P2WHITE_1' at index: 139
# dropping 'P2HISPRM_1' at index: 140
# dropping 'P2ENRL_1' at index: 141
# dropping 'P2EMPL_3' at index: 144
# dropping 'FHCAMT_1' at index: 175
# dropping 'HDRECSER_1' at index: 190
# dropping 'HDSPCLED_1' at index: 191
# dropping 'HDLEARN_1' at index: 192
# dropping 'HDPLAY_1' at index: 193
# dropping 'HDOUT_1' at index: 194
# dropping 'DISBLTY2X_2' at index: 205
# dropping 'P2EMPL_1' at index: 142
# dropping 'CSPEAKX_2' at index: 63
# dropping 'HDTRBRAIN_2' at index: 186
# dropping 'CPACI_2' at index: 198
# dropping 'HDPDDX_2' at index: 182
# dropping 'P1PACI_2' at index: 97
# dropping 'P1HISPRM_2' at index: 98
# dropping 'P2PACI_2' at index: 135
# dropping 'HDDEAFIMX_2' at index: 175
# dropping 'P1AMIND_2' at index: 94
# dropping 'P1ASIAN_2' at index: 94
# dropping 'HDINTDIS_2' at index: 170
# dropping 'HDBLINDX_2' at index: 172
# dropping 'P2AMIND_2' at index: 130
# dropping 'CHISPRM_2' at index: 189
# dropping 'HDORTHOX_2' at index: 171
# dropping 'HDAUTISMX_2' at index: 171
# dropping 'FHPLACE_1' at index: 201
# dropping 'P1BLACK_2' at index: 94
# dropping 'HWELFTAN_2' at index: 142
# dropping 'HSECN8_2' at index: 147
# dropping 'P2ASIAN_2' at index: 129
# dropping 'HDDELAYX_2' at index: 169
# dropping 'CAMIND_2' at index: 178
# dropping 'HDDISTRBX_2' at index: 166
# dropping 'HWIC_2' at index: 142
# dropping 'HDOTHERX_2' at index: 167
# dropping 'P2HISPRM_2' at index: 131
# dropping 'HWELFST_2' at index: 140
# dropping 'P2BLACK_2' at index: 129
# dropping 'SEFUTUREX_6' at index: 180
# dropping 'SCHRTSCHL_2' at index: 46
# dropping 'HDFRNDS_2' at index: 169
# dropping 'P1HISPAN_2' at index: 92
# dropping 'CASIAN_2' at index: 169
# dropping 'P1SEX_2' at index: 72
# dropping 'HDSPEECHX_2' at index: 158
# dropping 'SNETCRSX_2' at index: 53
# dropping 'P2ENRL_2' at index: 126
# dropping 'P1BFGF_2' at index: 75
# dropping 'P2HISPAN_2' at index: 123
# dropping 'HDLEARNX_2' at index: 155
# dropping 'HHTOTALXX' at index: 17
# dropping 'P1ENRL_2' at index: 89
# dropping 'P2BFGF_1' at index: 105
# dropping 'FSCOMMTE_2' at index: 172
# dropping 'CBLACK_2' at index: 159
# dropping 'HCHIP_2' at index: 131
# dropping 'HDADDX_2' at index: 150
# dropping 'HFOODST_2' at index: 129
# dropping 'P1WRMTL_1' at index: 84
# dropping 'P2MTHSWRK' at index: 36
# dropping 'CHISPAN_2' at index: 153
# dropping 'HDOUT_2' at index: 151
# dropping 'FOZOOX_2' at index: 178
# dropping 'CWHITE_2' at index: 152
# dropping 'SNEIGHBRX_2' at index: 44
# dropping 'P2WRMTL_1' at index: 113
# dropping 'HMEDICAID_2' at index: 125
# dropping 'P1SPEAK_3' at index: 76
# dropping 'FOMUSEUMX_2' at index: 172
# dropping 'CLIVYN_2' at index: 57
# dropping 'P1MTHSWRK' at index: 31
# dropping 'P2HRSWK' at index: 34
# dropping 'HDPLAY_2' at index: 143
# dropping 'FSVOL_2' at index: 150
# dropping 'P1HRSWK' at index: 30
# dropping 'P2FRLNG_3' at index: 98
# dropping 'FOCRAFTS_2' at index: 156
# Remaining variables:
# Index(['FSFREQ', 'FSSPPERF', 'FSSPHW', 'FSSPCOUR', 'FSSPROLE', 'FSSPCOLL',
#        'FCSCHOOL', 'FCTEACHR', 'FCSTDS', 'FCORDER',
#        ...
#        'FOSPORT_2', 'FORESPON_2', 'FOHISTX_2', 'FOLIBRAYX_2', 'FOBOOKSTX_2',
#        'FOCONCRTX_2', 'FOGROUPX_2', 'FOSPRTEVX_2', 'HDDEVIEPX_1',
#        'HDDEVIEPX_2'],
#       dtype='object', length=168)

# %%
X_train_upd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15826 entries, 0 to 15825
# Columns: 168 entries, FSFREQ to HDDEVIEPX_2
# dtypes: float64(168)
# memory usage: 20.3 MB

# %%
X_train_upd.to_csv('X_train_upd.csv')

# %%
import statsmodels.api as sm

# %%
X_train_upd_0 = sm.add_constant(X_train_upd)
logit_mod = sm.Logit(y_train, X_train_upd_0)

# %%
N = y_train.shape[0]
K = X_train_upd_0.shape[1]

# %%
a_array = np.linspace(0.0001, 0.01, 100)
auc_list = []
for a in a_array:
    alpha = a * N * np.ones(K)
    logit_res = logit_mod.fit_regularized(method = 'l1', alpha = alpha)
    y_train_score = logit_res.predict(X_train_upd_0)
    fpr, tpr, thresholds = roc_curve(y_train, y_train_score)
    auc_list.append(auc(fpr, tpr))
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.39807026505139237
#             Iterations: 579
#             Function evaluations: 579
#             Gradient evaluations: 579
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4032274637345377
#             Iterations: 484
#             Function evaluations: 484
#             Gradient evaluations: 484
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.40766579552428545
#             Iterations: 405
#             Function evaluations: 405
#             Gradient evaluations: 405
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.41157310325726326
#             Iterations: 373
#             Function evaluations: 373
#             Gradient evaluations: 373
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.41518436012363286
#             Iterations: 365
#             Function evaluations: 366
#             Gradient evaluations: 365
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.418561459558115
#             Iterations: 354
#             Function evaluations: 355
#             Gradient evaluations: 354
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4217259000674032
#             Iterations: 347
#             Function evaluations: 347
#             Gradient evaluations: 347
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4246980494812769
#             Iterations: 340
#             Function evaluations: 341
#             Gradient evaluations: 340
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.42750367026018765
#             Iterations: 326
#             Function evaluations: 327
#             Gradient evaluations: 326
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4301673768525315
#             Iterations: 301
#             Function evaluations: 301
#             Gradient evaluations: 301
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4327130337664364
#             Iterations: 288
#             Function evaluations: 288
#             Gradient evaluations: 288
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4351517312112173
#             Iterations: 268
#             Function evaluations: 269
#             Gradient evaluations: 268
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.43749300156188675
#             Iterations: 246
#             Function evaluations: 247
#             Gradient evaluations: 246
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.43974188927042973
#             Iterations: 235
#             Function evaluations: 236
#             Gradient evaluations: 235
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.44190190599505313
#             Iterations: 236
#             Function evaluations: 236
#             Gradient evaluations: 236
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.44398329185533514
#             Iterations: 232
#             Function evaluations: 232
#             Gradient evaluations: 232
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.44599410196964234
#             Iterations: 188
#             Function evaluations: 189
#             Gradient evaluations: 188
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4479383164623888
#             Iterations: 200
#             Function evaluations: 200
#             Gradient evaluations: 200
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.44982232063758215
#             Iterations: 204
#             Function evaluations: 205
#             Gradient evaluations: 204
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4516494154255369
#             Iterations: 186
#             Function evaluations: 187
#             Gradient evaluations: 186
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.45342679639163885
#             Iterations: 161
#             Function evaluations: 161
#             Gradient evaluations: 161
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.455159554521263
#             Iterations: 164
#             Function evaluations: 164
#             Gradient evaluations: 164
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4568519619578427
#             Iterations: 162
#             Function evaluations: 162
#             Gradient evaluations: 162
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.45850560636131754
#             Iterations: 161
#             Function evaluations: 161
#             Gradient evaluations: 161
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46012128692939136
#             Iterations: 159
#             Function evaluations: 160
#             Gradient evaluations: 159
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4616994536383022
#             Iterations: 158
#             Function evaluations: 158
#             Gradient evaluations: 158
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46324238757332425
#             Iterations: 151
#             Function evaluations: 152
#             Gradient evaluations: 151
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46475511472158665
#             Iterations: 142
#             Function evaluations: 143
#             Gradient evaluations: 142
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46623894237158264
#             Iterations: 147
#             Function evaluations: 148
#             Gradient evaluations: 147
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4676948830273102
#             Iterations: 143
#             Function evaluations: 144
#             Gradient evaluations: 143
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46912440653451526
#             Iterations: 143
#             Function evaluations: 144
#             Gradient evaluations: 143
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47052976452219947
#             Iterations: 143
#             Function evaluations: 143
#             Gradient evaluations: 143
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47191274331796995
#             Iterations: 135
#             Function evaluations: 135
#             Gradient evaluations: 135
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4732736511988934
#             Iterations: 126
#             Function evaluations: 127
#             Gradient evaluations: 126
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4746134506337936
#             Iterations: 130
#             Function evaluations: 130
#             Gradient evaluations: 130
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47593309453637445
#             Iterations: 123
#             Function evaluations: 124
#             Gradient evaluations: 123
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4772329928472575
#             Iterations: 123
#             Function evaluations: 123
#             Gradient evaluations: 123
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47851337749682427
#             Iterations: 122
#             Function evaluations: 123
#             Gradient evaluations: 122
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4797744337144204
#             Iterations: 123
#             Function evaluations: 123
#             Gradient evaluations: 123
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48101672582558896
#             Iterations: 119
#             Function evaluations: 120
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48224058122716534
#             Iterations: 119
#             Function evaluations: 119
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.483446149661227
#             Iterations: 117
#             Function evaluations: 118
#             Gradient evaluations: 117
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48463372336170896
#             Iterations: 118
#             Function evaluations: 119
#             Gradient evaluations: 118
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4858037239763308
#             Iterations: 119
#             Function evaluations: 120
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48695633408079525
#             Iterations: 119
#             Function evaluations: 120
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48809168353219545
#             Iterations: 119
#             Function evaluations: 120
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4892098986998002
#             Iterations: 119
#             Function evaluations: 120
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4903111117208588
#             Iterations: 120
#             Function evaluations: 120
#             Gradient evaluations: 120
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4913956453753209
#             Iterations: 115
#             Function evaluations: 116
#             Gradient evaluations: 115
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4924650299601395
#             Iterations: 115
#             Function evaluations: 116
#             Gradient evaluations: 115
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4935209977944012
#             Iterations: 108
#             Function evaluations: 109
#             Gradient evaluations: 108
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49456404820288674
#             Iterations: 113
#             Function evaluations: 113
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4955958005445164
#             Iterations: 112
#             Function evaluations: 112
#             Gradient evaluations: 112
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4966177626059671
#             Iterations: 110
#             Function evaluations: 111
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49763023713585763
#             Iterations: 113
#             Function evaluations: 113
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49863328822914205
#             Iterations: 112
#             Function evaluations: 113
#             Gradient evaluations: 112
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49962697464638495
#             Iterations: 112
#             Function evaluations: 112
#             Gradient evaluations: 112
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5006113546906276
#             Iterations: 113
#             Function evaluations: 113
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5015864943416662
#             Iterations: 113
#             Function evaluations: 114
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5025524632706593
#             Iterations: 113
#             Function evaluations: 113
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5035093160575038
#             Iterations: 114
#             Function evaluations: 115
#             Gradient evaluations: 114
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5044571077777915
#             Iterations: 110
#             Function evaluations: 110
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5053958906455465
#             Iterations: 110
#             Function evaluations: 110
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5063257174224927
#             Iterations: 110
#             Function evaluations: 110
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5072466866272299
#             Iterations: 110
#             Function evaluations: 110
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5081594822335749
#             Iterations: 105
#             Function evaluations: 106
#             Gradient evaluations: 105
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5090649878624248
#             Iterations: 113
#             Function evaluations: 114
#             Gradient evaluations: 113
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5099632866654775
#             Iterations: 110
#             Function evaluations: 111
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5108544449726826
#             Iterations: 110
#             Function evaluations: 110
#             Gradient evaluations: 110
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5117385234989464
#             Iterations: 109
#             Function evaluations: 109
#             Gradient evaluations: 109
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5126155587940976
#             Iterations: 108
#             Function evaluations: 109
#             Gradient evaluations: 108
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5134855871505086
#             Iterations: 108
#             Function evaluations: 109
#             Gradient evaluations: 108
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5143486444013882
#             Iterations: 107
#             Function evaluations: 107
#             Gradient evaluations: 107
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.515204765526331
#             Iterations: 107
#             Function evaluations: 107
#             Gradient evaluations: 107
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5160539851522687
#             Iterations: 106
#             Function evaluations: 106
#             Gradient evaluations: 106
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5168963373309376
#             Iterations: 106
#             Function evaluations: 106
#             Gradient evaluations: 106
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5177318600515428
#             Iterations: 102
#             Function evaluations: 103
#             Gradient evaluations: 102
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5185607648067032
#             Iterations: 102
#             Function evaluations: 103
#             Gradient evaluations: 102
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5193833734345146
#             Iterations: 107
#             Function evaluations: 107
#             Gradient evaluations: 107
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5201997242093839
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5210098450261695
#             Iterations: 102
#             Function evaluations: 102
#             Gradient evaluations: 102
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5218137704569126
#             Iterations: 104
#             Function evaluations: 105
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5226115632713896
#             Iterations: 105
#             Function evaluations: 105
#             Gradient evaluations: 105
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5234032567902177
#             Iterations: 104
#             Function evaluations: 105
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5241889090120555
#             Iterations: 106
#             Function evaluations: 106
#             Gradient evaluations: 106
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5249686971775194
#             Iterations: 107
#             Function evaluations: 107
#             Gradient evaluations: 107
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5257429059706981
#             Iterations: 101
#             Function evaluations: 102
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5265116321143426
#             Iterations: 101
#             Function evaluations: 101
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5272748993153688
#             Iterations: 101
#             Function evaluations: 102
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5280327310587075
#             Iterations: 100
#             Function evaluations: 101
#             Gradient evaluations: 100
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5287851496309198
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5295321786892461
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5302738408683921
#             Iterations: 97
#             Function evaluations: 98
#             Gradient evaluations: 97
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5310101651948668
#             Iterations: 106
#             Function evaluations: 107
#             Gradient evaluations: 106
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5317412751580683
#             Iterations: 104
#             Function evaluations: 105
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.532467215779827
#             Iterations: 104
#             Function evaluations: 104
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5331880074782468
#             Iterations: 104
#             Function evaluations: 104
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5339036706250264
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.534614225193042
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5353196909784166
#             Iterations: 103
#             Function evaluations: 104
#             Gradient evaluations: 103

# %%
plt.plot(a_array, auc_list)

# %%
a_array
# Out:
# array([0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008,
#        0.0009, 0.001 , 0.0011, 0.0012, 0.0013, 0.0014, 0.0015, 0.0016,
#        0.0017, 0.0018, 0.0019, 0.002 , 0.0021, 0.0022, 0.0023, 0.0024,
#        0.0025, 0.0026, 0.0027, 0.0028, 0.0029, 0.003 , 0.0031, 0.0032,
#        0.0033, 0.0034, 0.0035, 0.0036, 0.0037, 0.0038, 0.0039, 0.004 ,
#        0.0041, 0.0042, 0.0043, 0.0044, 0.0045, 0.0046, 0.0047, 0.0048,
#        0.0049, 0.005 , 0.0051, 0.0052, 0.0053, 0.0054, 0.0055, 0.0056,
#        0.0057, 0.0058, 0.0059, 0.006 , 0.0061, 0.0062, 0.0063, 0.0064,
#        0.0065, 0.0066, 0.0067, 0.0068, 0.0069, 0.007 , 0.0071, 0.0072,
#        0.0073, 0.0074, 0.0075, 0.0076, 0.0077, 0.0078, 0.0079, 0.008 ,
#        0.0081, 0.0082, 0.0083, 0.0084, 0.0085, 0.0086, 0.0087, 0.0088,
#        0.0089, 0.009 , 0.0091, 0.0092, 0.0093, 0.0094, 0.0095, 0.0096,
#        0.0097, 0.0098, 0.0099, 0.01  ])

# %%
a = 0.0002
alpha = a * N * np.ones(K)
logit_res = logit_mod.fit_regularized(method = 'l1', alpha = alpha)
print(logit_res.summary())
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4032274637345377
#             Iterations: 484
#             Function evaluations: 484
#             Gradient evaluations: 484
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               SEGRADES   No. Observations:                15826
# Model:                          Logit   Df Residuals:                    15680
# Method:                           MLE   Df Model:                          145
# Date:                Sat, 22 Feb 2020   Pseudo R-squ.:                  0.4321
# Time:                        07:57:37   Log-Likelihood:                -6230.1
# converged:                       True   LL-Null:                       -10970.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.5818      0.156     10.156      0.000       1.277       1.887
# FSFREQ           0.0971      0.030      3.211      0.001       0.038       0.156
# FSSPPERF        -0.2146      0.033     -6.443      0.000      -0.280      -0.149
# FSSPHW           0.0437      0.038      1.160      0.246      -0.030       0.118
# FSSPCOUR         0.0381      0.038      1.003      0.316      -0.036       0.113
# FSSPROLE         0.0677      0.038      1.764      0.078      -0.008       0.143
# FSSPCOLL        -0.0738      0.031     -2.344      0.019      -0.135      -0.012
# FCSCHOOL        -0.3756      0.041     -9.064      0.000      -0.457      -0.294
# FCTEACHR        -0.2793      0.035     -8.090      0.000      -0.347      -0.212
# FCSTDS          -0.0865      0.038     -2.279      0.023      -0.161      -0.012
# FCORDER          0.1420      0.035      4.022      0.000       0.073       0.211
# FCSUPPRT         0.1883      0.038      4.946      0.000       0.114       0.263
# FHHOME           0.1355      0.035      3.893      0.000       0.067       0.204
# SEFUTUREX_2     -2.2359      0.105    -21.256      0.000      -2.442      -2.030
# SEFUTUREX_3     -2.1911      0.096    -22.761      0.000      -2.380      -2.002
# SEFUTUREX_4     -1.5064      0.074    -20.294      0.000      -1.652      -1.361
# SEFUTUREX_5     -0.7184      0.065    -11.026      0.000      -0.846      -0.591
# FSSPORTX_2      -0.6137      0.065     -9.458      0.000      -0.741      -0.486
# FSMTNG_2        -0.0285      0.074     -0.387      0.699      -0.173       0.116
# FSPTMTNG_2       0.0462      0.054      0.857      0.391      -0.059       0.152
# FSATCNFN_2       0.3040      0.063      4.842      0.000       0.181       0.427
# FSFUNDRS_2      -0.2033      0.057     -3.554      0.000      -0.315      -0.091
# FSCOUNSLR_2      0.4287      0.055      7.804      0.000       0.321       0.536
# FHPLACE_2        0.3977      0.078      5.111      0.000       0.245       0.550
# FHPLACE_3       -0.4986      0.242     -2.061      0.039      -0.973      -0.024
# FOSTORY2X_2     -0.0528      0.054     -0.975      0.329      -0.159       0.053
# FOGAMES_2       -0.0493      0.055     -0.901      0.367      -0.157       0.058
# FOBUILDX_2      -0.1693      0.054     -3.159      0.002      -0.274      -0.064
# FOSPORT_2       -0.2307      0.060     -3.868      0.000      -0.348      -0.114
# FORESPON_2       0.3025      0.062      4.918      0.000       0.182       0.423
# FOHISTX_2        0.2164      0.055      3.930      0.000       0.108       0.324
# FOLIBRAYX_2           0        nan        nan        nan         nan         nan
# FOBOOKSTX_2     -0.0978      0.056     -1.738      0.082      -0.208       0.012
# FOCONCRTX_2     -0.1677      0.056     -2.976      0.003      -0.278      -0.057
# FOGROUPX_2      -0.1805      0.052     -3.458      0.001      -0.283      -0.078
# FOSPRTEVX_2     -0.0315      0.054     -0.583      0.560      -0.137       0.074
# HDDEVIEPX_1     -0.6825      0.092     -7.428      0.000      -0.863      -0.502
# HDDEVIEPX_2     -1.1707      0.286     -4.088      0.000      -1.732      -0.609
# ================================================================================

# %%
y_train_score = logit_res.predict(X_train_upd_0)
y_train_hat = y_train_score > 0.5
print(classification_report(y_train, y_train_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      7913
#            1       0.83      0.82      0.83      7913
#
#     accuracy                           0.83     15826
#    macro avg       0.83      0.83      0.83     15826
# weighted avg       0.83      0.83      0.83     15826

# %%
fpr, tpr, thresholds = roc_curve(y_train, y_train_score)
print('AUC: {}'.format(auc(fpr, tpr)))
roc_plot(fpr, tpr)
# Out:
# AUC: 0.9028518769828635

# %% [markdown]
# ### Test

# %%
X_test_upd = X_test[X_train_upd.columns]
X_test_upd_0 = sm.add_constant(X_test_upd)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
y_test_score = logit_res.predict(X_test_upd_0)
y_test_hat = y_test_score > 0.5
print(classification_report(y_test, y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.84      0.43       327
#            1       0.96      0.66      0.78      1979
#
#     accuracy                           0.68      2306
#    macro avg       0.62      0.75      0.60      2306
# weighted avg       0.87      0.68      0.73      2306

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_test_score)
print('AUC: {}'.format(auc(fpr, tpr)))
roc_plot(fpr, tpr)
# Out:
# AUC: 0.8285143857599596
